# %% [markdown]
# <a href="https://colab.research.google.com/github/mercykdiazv/Bici-al-Trabajo-2026./blob/main/17022026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola Ingenieros Industriales")
# Out:
# Hola Ingenieros Industriales

# %%
print("Este semestre vamos a mejorar un proceso con datos")
# Out:
# Este semestre vamos a mejorar un proceso con datos

# %%
ventas=15000000
costos=9000000
utilidad=ventas-costos
print(utilidad)
# Out:
# 6000000

# %%
nombre_empresa = "Casam"
ventas =[1200, 1500, 1100, 1700]
total= sum(ventas)
print("Empresa:" ,nombre_empresa)
print("total ventas:", total)
# Out:
# Empresa: Casam
# total ventas: 5500

# %%
produccion_dia1 = 120
produccion_dia2 = 135
total_produccion = produccion_dia1 + produccion_dia2
print("produccion total:" , total_produccion)
# Out:
# produccion total: 255

# %%
produccion_total = 500
dias_trabajados = 5
promedio_diario = produccion_total/dias_trabajados
print("Promedio diario de produccion" , promedio_diario)
# Out:
# Promedio diario de produccion 100.0

# %%
ventas = [1000, 1500, 1300, 1700]
total = sum(ventas)
cantidad = len(ventas)
promedio = total/cantidad
print("Promedio de ventas:" , promedio)
# Out:
# Promedio de ventas: 1375.0

# %%
#Este programa calcula la utilidad de una empresa
ventas=15000000
costos=9000000
utilidad=ventas-costos
print("La utilidad es:" , utilidad)
# Out:
# La utilidad es: 6000000
